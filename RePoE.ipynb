# %%
import json
import os
from collections import defaultdict
from pathlib import Path

from termcolor import cprint

from poe_types import PoEItem, PoEMod
from utils import loadRecombsFromFileList, validateAndReturn

# %%
# Load recomb files for easy PoEItems
json_dir = Path().parent / 'data/json'
recombination_files = sorted(os.listdir(json_dir))
recombination_files_full = [json_dir / name for name in recombination_files]
recombs = loadRecombsFromFileList(recombination_files_full)
print(len(recombs))
# Out:
# 264

# %%
data_path = Path('../RePoE/RePoE/data').resolve()

# %%
with open(data_path / 'mods.json') as f:
    j = json.load(f)
jkl = list(j.keys())
print(len(jkl))
print(jkl[:50])
# Out:
# 36720
# ['Strength1', 'Strength2', 'Strength3', 'Strength4', 'Strength5', 'Strength6', 'Strength7', 'Strength8', 'Strength9', 'Strength10', 'StrengthEssence7_', 'StrengthUniqueRing2', 'StrengthImplicitAmulet1', 'StrengthImplicitBelt1', 'StrengthImplicitBeltRoyale1', 'StrengthUniqueHelmetDexInt1', 'StrengthUniqueTwoHandMace1', 'StrengthUniqueAmulet5', 'StrengthUniqueIntHelmet3', 'StrengthUniqueBootsInt1', 'StrengthUniqueDagger2', 'StrengthUniqueBootsStrDex1', 'StrengthUniqueBootsStrDex1Royale', 'StrengthUniqueGlovesDex1', 'StrengthUniqueBelt1', 'StrengthUniqueBelt2', 'StrengthUniqueBelt4', 'StrengthUniqueGlovesStr2', 'StrengthUniqueTwoHandAxe3', 'StrengthUniqueBodyStrInt3', 'StrengthUniqueGlovesStrDex3', 'StrengthUniqueHelmetStrDex3', 'StrengthUniqueClaw5_', 'StrengthUniqueRing8', 'StrengthUniqueBootsDexInt2', 'StrengthUniqueTwoHandAxe5', 'StrengthUniqueTwoHandSword5', 'StrengthUniqueBelt7', 'StrengthUniqueSceptre6', 'StrengthUniqueBodyStr4', 'StrengthUniqueQuiver6', 'StrengthUniqueOneHandSword8', 'StrengthUniqueGlovesStrInt2', 'StrengthUniqueRing31__', 'StrengthUniqueClaw9', 'StrengthUniqueRing36', 'StrengthUnique__1', 'StrengthUnique___2', 'StrengthUnique__3', 'StrengthUnique__4']

# %%
# Mods from RePoE don't have int before (), but mods from in game do
# Need to handle both cases
mod_text_examples = [
    '(55-64)% increased Physical Damage\n+(124-149) to Accuracy Rating',
    'Adds 11(11-14) to 25(21-25) Physical Damage',
    'Adds (16-22) to (35-40) Physical Damage',
    '32% reduced Attribute Requirements',
]

def convertModTextToGeneric(mod_text):
    lines = mod_text.split('\n')
    generic_lines = []
    for l in lines:
        # https://regex101.com/r/AjXLZe/1
        quantity_matches = validateAndReturn(l, r'([\d\.]+)?(\([\d\-\.].*?\))?')
        quantity_matches = [q for q in quantity_matches if q != ('', '')]
        if len(quantity_matches) == 0:
            # Non number modification like "Hits have Culling Strike"
            generic_lines.append(l)
        else:
            # Some number modification like "Adds 20(20-26) to 47(40-47) Physical Damage"
            # For description, replace number data with X, so output is "Adds X to X Physical Damage"
            # https://regex101.com/r/05b4zw/1
            output_description = []
            last_idx = 0
            for match in quantity_matches:
                full_match = ''.join(match)
                start_index = l.index(full_match)
                end_index = start_index + len(full_match)
                if start_index > last_idx:
                    output_description.append(l[last_idx:start_index])
                output_description.append('X')
                last_idx = end_index
            if last_idx < len(l):
                output_description.append(l[last_idx:])
            output_description = ''.join(output_description)
    
            generic_lines.append(output_description)
    
    return '\n'.join(generic_lines)


for mod_text in mod_text_examples:
    g = convertModTextToGeneric(mod_text)
    print(g)
    print()
# Out:
# X% increased Physical Damage
# +X to Accuracy Rating
#
# Adds X to X Physical Damage
#
# Adds X to X Physical Damage
#
# X% reduced Attribute Requirements

# %%
with open(data_path / 'base_items.json') as f:
    base_items = json.load(f)
print(len(base_items))
# Out:
# 4756

# %%
print(base_items['Metadata/Items/Weapons/OneHandWeapons/OneHandAxes/OneHandAxe18'])
# Out:
# {'domain': 'item', 'drop_level': 61, 'implicits': [], 'inventory_height': 3, 'inventory_width': 2, 'inherits_from': 'Metadata/Items/Weapons/OneHandWeapons/OneHandAxes/AbstractOneHandAxe', 'item_class': 'One Hand Axe', 'name': 'Reaver Axe', 'properties': {'armour': None, 'energy_shield': None, 'evasion': None, 'movement_speed': None, 'block': None, 'description': None, 'directions': None, 'stack_size': None, 'stack_size_currency_tab': None, 'full_stack_turns_into': None, 'charges_max': None, 'charges_per_use': None, 'duration': None, 'life_per_use': None, 'mana_per_use': None, 'attack_time': 833, 'critical_strike_chance': 500, 'physical_damage_max': 114, 'physical_damage_min': 38, 'range': 11, 'mana_burn_ms': None, 'cooldown_ms': None, 'monster_id': None, 'monster_ability_text': None, 'monster_category': None}, 'release_state': 'released', 'tags': ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default'], 'visual_identity': {'dds_file': 'Art/2DItems/Weapons/OneHandWeapons/OneHandAxes/OneHandAxe4.dds', 'id': 'OneHandAxe4'}, 'requirements': {'dexterity': 57, 'intelligence': 0, 'level': 61, 'strength': 167}, 'grants_buff': None}

# %%
reaver_class = base_items['Metadata/Items/Weapons/OneHandWeapons/OneHandAxes/OneHandAxe18']
reaver_class
# Out:
# {'domain': 'item',
#  'drop_level': 61,
#  'implicits': [],
#  'inventory_height': 3,
#  'inventory_width': 2,
#  'inherits_from': 'Metadata/Items/Weapons/OneHandWeapons/OneHandAxes/AbstractOneHandAxe',
#  'item_class': 'One Hand Axe',
#  'name': 'Reaver Axe',
#  'properties': {'armour': None,
#   'energy_shield': None,
#   'evasion': None,
#   'movement_speed': None,
#   'block': None,
#   'description': None,
#   'directions': None,
#   'stack_size': None,
#   'stack_size_currency_tab': None,
#   'full_stack_turns_into': None,
#   'charges_max': None,
#   'charges_per_use': None,
#   'duration': None,
#   'life_per_use': None,
#   'mana_per_use': None,
#   'attack_time': 833,
#   'critical_strike_chance': 500,
#   'physical_damage_max': 114,
#   'physical_damage_min': 38,
#   'range': 11,
#   'mana_burn_ms': None,
#   'cooldown_ms': None,
#   'monster_id': None,
#   'monster_ability_text': None,
#   'monster_category': None},
#  'release_state': 'released',
#  'tags': ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default'],
#  'visual_identity': {'dds_file': 'Art/2DItems/Weapons/OneHandWeapons/OneHandAxes/OneHandAxe4.dds',
#   'id': 'OneHandAxe4'},
#  'requirements': {'dexterity': 57,
#   'intelligence': 0,
#   'level': 61,
#   'strength': 167},
#  'grants_buff': None}

# %%
# Construct base_item_to_iclass mapping
print_counter = 0
max_print = 20
# print(base_items['Metadata/Items/Weapons/OneHandWeapons/OneHandAxes/OneHandAxe1'].keys())
base_item_to_iclass = defaultdict(list)
for k, v in base_items.items():
    base_item_to_iclass[v['name']].append(k)
    
    short_key = k.split('/')[-1]
    if print_counter < max_print:
        if 'one_hand_weapon' in v['tags'] and short_key.startswith('OneHand'):
            print(short_key, v['tags'])
            print_counter += 1
# Out:
# OneHandAxe1 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe2 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe3 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe4 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe5 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe6 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe7 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe8 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxeM1 ['not_for_sale', 'maraketh', 'axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe9 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe10 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe11 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe12 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe13 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe14 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe15 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxeM2 ['not_for_sale', 'maraketh', 'axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe16 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe17 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']
# OneHandAxe18 ['axe', 'one_hand_weapon', 'onehand', 'weapon', 'default']

# %%
matching_ids_for_text = defaultdict(list)
for mod_id, info in j.items():
    if mod_id.startswith('WeaponTree'):
        # Ignore Crucible mods
        continue
    elif info.get('generation_type', 'N/A') in {'unique', 'scourge_benefit'}:
        # Ignore various impossible sources or things out of league
        continue
    else:
        # Ignore mods that cannot spawn
        pass # A lot of useful mods like essence and beastcraft do not have spawn weights
        # spawn_weights = info.get('spawn_weights')
        # if spawn_weights is not None:
        #     if not any([w['weight'] > 0 for w in spawn_weights]):
        #         continue
    
    # Convert to generic form
    mod_text = info['text']
    if mod_text is not None:
        g = convertModTextToGeneric(mod_text)
        matching_ids_for_text[g].append(mod_id)
    else:
        # There are lot of these but mostly seem to be uniques or monster mods, which aren't useful
        continue

def convertItemModsToId(item: PoEItem):
    output_mods = []
    for m in item.mods:
        text = m.stringDescription()
        possible_matches = matching_ids_for_text[text]

        if len(possible_matches) == 1:
            output_mods.append(possible_matches[0])
            continue
        
        # Check other data specified in original mod and see which ones match
        mined_info = {mod_id: j[mod_id] for mod_id in possible_matches}
    
        # Modifier title check (eg "of Craft")
        if m.title != '':
            possible_matches = [
                mod_id for mod_id in possible_matches
                if m.title == mined_info[mod_id]['name']
            ]

        if len(possible_matches) == 1:
            output_mods.append(possible_matches[0])
            continue
        
        # Check if weapon type can have said modifiers
        # If there are non-matching mods for "spawn_weighting" list then it is impossible to have the mod
        # TODO: ^^ Unfortunately this simple rule isn't true, it's probably some class OOP stuff
        # Look up iclass of item using base name
        iclass = base_item_to_iclass[item.base]
        if len(iclass) == 1:
            iclass = iclass[0]
            allowed_class_tags = set(base_items[iclass]['tags'])
            new_possible_matches = []
            for mod_id in possible_matches:
                mod_allowed_spawns = set([w['tag'] for w in mined_info[mod_id]['spawn_weights']])
                overlapping_tags = mod_allowed_spawns & allowed_class_tags
                print(overlapping_tags)
                if len(overlapping_tags) > 1: # excluding "default" tag
                    new_possible_matches.append(mod_id)
            possible_matches = new_possible_matches
        
        if len(possible_matches) == 1:
            output_mods.append(possible_matches[0])
            continue
        
        output_mods.append(possible_matches)
    return output_mods

# %%
chosen_item = recombs['00139.json']['input1']
for m in chosen_item.mods:
    print(f'"{m.stringDescription()}"')
print('==========')
mod_ids = convertItemModsToId(chosen_item)
# print(mod_ids)
print_keys = [
    'generation_type',
    'text',
]
print(mod_ids)
for mod_matches in mod_ids:
    if isinstance(mod_matches, str):
        cprint(mod_matches, 'green')
        print('  -----')
    else:
        for mod_id in mod_matches:
            print('  ', mod_id)
            print('     ', end='')
            for k in print_keys:
                print(j[mod_id].get(k), end=' | ')
            print()
        if len(mod_matches) == 0:
            cprint('NO MATCH', 'red')
        print('  -----')
# Out:
# "Adds X to X Fire Damage"
# "Adds X to X Physical Damage"
# "Socketed Gems are Supported by Level X Chance To Bleed — Unscalable Value
# X% chance to cause Bleeding on Hit"
# "+X% to Chaos Resistance"
# "X% reduced Attribute Requirements"
# ==========
# {'default', 'axe'}
# {'default', 'one_hand_weapon', 'axe'}
# {'default'}
# {'default'}
# {'default'}
# {'default'}
# {'default', 'one_hand_weapon'}
# {'default'}
# [['LocalAddedFireDamage4', 'LocalAddedFireDamageTwoHand4'], 'LocalAddedPhysicalDamage5', [], 'ChaosResist3', 'ReducedLocalAttributeRequirements2']
#    LocalAddedFireDamage4
#      prefix | Adds (17-24) to (35-41) Fire Damage |
#    LocalAddedFireDamageTwoHand4
#      prefix | Adds (32-44) to (65-76) Fire Damage |
#   -----
# LocalAddedPhysicalDamage5
#   -----
# NO MATCH
#   -----
# ChaosResist3
#   -----
# ReducedLocalAttributeRequirements2
#   -----

# %%
text_to_id = {}
print_counter = 0
max_print = 3
for mod_id, info in j.items():
    if info['text'] is not None:
        lt = info['text'].lower()
        if mod_id.startswith('LocalAddedPhysicalDamage') and info.get('generation_type', '') != 'unique':
            print(mod_id)
            print(info)
            print()
            print_counter += 1
            if max_print == print_counter:
                break
# Out:
# LocalAddedPhysicalDamage1
# {'adds_tags': ['has_attack_mod'], 'domain': 'item', 'generation_type': 'prefix', 'generation_weights': [{'tag': 'has_attack_mod', 'weight': 100}, {'tag': 'has_caster_mod', 'weight': 65}, {'tag': 'default', 'weight': 100}], 'grants_effects': [], 'groups': ['PhysicalDamage'], 'implicit_tags': ['physical_damage', 'damage', 'physical', 'attack'], 'is_essence_only': False, 'name': 'Glinting', 'required_level': 2, 'spawn_weights': [{'tag': 'one_hand_weapon', 'weight': 1000}, {'tag': 'default', 'weight': 0}], 'stats': [{'id': 'local_minimum_added_physical_damage', 'max': 1, 'min': 1}, {'id': 'local_maximum_added_physical_damage', 'max': 3, 'min': 2}], 'text': 'Adds 1 to (2-3) Physical Damage', 'type': 'LocalPhysicalDamage'}
#
# LocalAddedPhysicalDamage2
# {'adds_tags': ['has_attack_mod'], 'domain': 'item', 'generation_type': 'prefix', 'generation_weights': [{'tag': 'has_attack_mod', 'weight': 100}, {'tag': 'has_caster_mod', 'weight': 65}, {'tag': 'default', 'weight': 100}], 'grants_effects': [], 'groups': ['PhysicalDamage'], 'implicit_tags': ['physical_damage', 'damage', 'physical', 'attack'], 'is_essence_only': False, 'name': 'Burnished', 'required_level': 13, 'spawn_weights': [{'tag': 'one_hand_weapon', 'weight': 1000}, {'tag': 'default', 'weight': 0}], 'stats': [{'id': 'local_minimum_added_physical_damage', 'max': 5, 'min': 4}, {'id': 'local_maximum_added_physical_damage', 'max': 9, 'min': 8}], 'text': 'Adds (4-5) to (8-9) Physical Damage', 'type': 'LocalPhysicalDamage'}
#
# LocalAddedPhysicalDamage3
# {'adds_tags': ['has_attack_mod'], 'domain': 'item', 'generation_type': 'prefix', 'generation_weights': [{'tag': 'has_attack_mod', 'weight': 100}, {'tag': 'has_caster_mod', 'weight': 65}, {'tag': 'default', 'weight': 100}], 'grants_effects': [], 'groups': ['PhysicalDamage'], 'implicit_tags': ['physical_damage', 'damage', 'physical', 'attack'], 'is_essence_only': False, 'name': 'Polished', 'required_level': 21, 'spawn_weights': [{'tag': 'one_hand_weapon', 'weight': 1000}, {'tag': 'default', 'weight': 0}], 'stats': [{'id': 'local_minimum_added_physical_damage', 'max': 9, 'min': 6}, {'id': 'local_maximum_added_physical_damage', 'max': 15, 'min': 13}], 'text': 'Adds (6-9) to (13-15) Physical Damage', 'type': 'LocalPhysicalDamage'}

# %%
j['Strength1']
# Out:
# {'adds_tags': [],
#  'domain': 'item',
#  'generation_type': 'suffix',
#  'generation_weights': [],
#  'grants_effects': [],
#  'groups': ['Strength'],
#  'implicit_tags': ['attribute'],
#  'is_essence_only': False,
#  'name': 'of the Brute',
#  'required_level': 1,
#  'spawn_weights': [{'tag': 'ring', 'weight': 1000},
#   {'tag': 'amulet', 'weight': 1000},
#   {'tag': 'belt', 'weight': 1000},
#   {'tag': 'str_armour', 'weight': 1000},
#   {'tag': 'str_dex_armour', 'weight': 1000},
#   {'tag': 'str_int_armour', 'weight': 1000},
#   {'tag': 'str_dex_int_armour', 'weight': 1000},
#   {'tag': 'sword', 'weight': 1000},
#   {'tag': 'mace', 'weight': 1000},
#   {'tag': 'sceptre', 'weight': 1000},
#   {'tag': 'staff', 'weight': 1000},
#   {'tag': 'axe', 'weight': 1000},
#   {'tag': 'default', 'weight': 0}],
#  'stats': [{'id': 'additional_strength', 'max': 12, 'min': 8}],
#  'text': '+(8-12) to Strength',
#  'type': 'Strength'}

# %%
for k, v in base_item_to_iclass.items():
    if len(v) > 1:
        print(k, v)
# Out:
# Corrupt ['Metadata/Items/Currency/CurrencyIncursionCorrupt1', 'Metadata/Items/Currency/CurrencyIncursionCorrupt2', 'Metadata/Items/Currency/CurrencyIncursionCorruptGem']
# Silver Coin ['Metadata/Items/Currency/CurrencySilverCoin', 'Metadata/Items/Currency/CurrencyAncestralSilverCoin']
# Fine Delirium Orb ['Metadata/Items/Currency/CurrencyAfflictionOrbCurrency', 'Metadata/Items/Currency/CurrencyAfflictionOrbProphecies']
# Delirium Orb ['Metadata/Items/Currency/CurrencyAfflictionOrbGeneric', 'Metadata/Items/Currency/CurrencyAfflictionOrbHardMode']
# Primitive Alchemical Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyUpgrade1', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyUpgrade1']
# Potent Alchemical Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyUpgrade2', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyUpgrade2']
# Powerful Alchemical Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyUpgrade3', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyUpgrade3']
# Prime Alchemical Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyUpgrade4', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyUpgrade4']
# Primitive Chaotic Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyReroll1', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyReroll1']
# Potent Chaotic Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyReroll2', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyReroll2']
# Powerful Chaotic Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyReroll3', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyReroll3']
# Prime Chaotic Resonator ['Metadata/Items/Delve/DelveSocketableCurrencyReroll4', 'Metadata/Items/Delve/DelveStackableSocketableCurrencyReroll4']
# Wrapped Gift ['Metadata/Items/MicrotransactionCurrency/GiftBox1x1', 'Metadata/Items/MicrotransactionCurrency/GiftBox1x2', 'Metadata/Items/MicrotransactionCurrency/GiftBox1x3', 'Metadata/Items/MicrotransactionCurrency/GiftBox1x4', 'Metadata/Items/MicrotransactionCurrency/GiftBox2x1', 'Metadata/Items/MicrotransactionCurrency/GiftBox2x2', 'Metadata/Items/MicrotransactionCurrency/GiftBox2x3', 'Metadata/Items/MicrotransactionCurrency/GiftBox2x4', 'Metadata/Items/MicrotransactionCurrency/GiftBox3x2', 'Metadata/Items/MicrotransactionCurrency/GiftBox3x1', 'Metadata/Items/MicrotransactionCurrency/GiftBox4x1']
# Driftwood Wand ['Metadata/Items/Weapons/OneHandWeapons/Wands/Wand1', 'Metadata/Items/Weapons/OneHandWeapons/Wands/Wand1Royale']
# Crude Bow ['Metadata/Items/Weapons/TwoHandWeapons/Bows/Bow1', 'Metadata/Items/Weapons/TwoHandWeapons/Bows/Bow1Royale']
# Paua Ring ['Metadata/Items/Rings/Ring3', 'Metadata/Items/Rings/RingRoyale4']
# Prismatic Ring ['Metadata/Items/Rings/Ring8', 'Metadata/Items/Rings/RingRoyale2']
# Diamond Ring ['Metadata/Items/Rings/Ring11', 'Metadata/Items/Rings/RingRoyale3']
# Two-Stone Ring ['Metadata/Items/Rings/Ring12', 'Metadata/Items/Rings/Ring13', 'Metadata/Items/Rings/Ring14']
# Shadowed Ring ['Metadata/Items/Rings/RingK5a', 'Metadata/Items/Rings/RingK5b', 'Metadata/Items/Rings/RingK5c']
# Opal Ring ['Metadata/Items/Rings/RingAtlas2', 'Metadata/Items/Rings/RingRoyale1']
# Onyx Amulet ['Metadata/Items/Amulets/Amulet7', 'Metadata/Items/Amulets/AmuletRoyale1']
# Avian Twins Talisman ['Metadata/Items/Amulets/Talismans/Talisman2_6_1', 'Metadata/Items/Amulets/Talismans/Talisman2_6_2', 'Metadata/Items/Amulets/Talismans/Talisman2_6_3', 'Metadata/Items/Amulets/Talismans/Talisman2_6_4', 'Metadata/Items/Amulets/Talismans/Talisman2_6_5', 'Metadata/Items/Amulets/Talismans/Talisman2_6_6']
# Monkey Paw Talisman ['Metadata/Items/Amulets/Talismans/Talisman3_6_1', 'Metadata/Items/Amulets/Talismans/Talisman3_6_2', 'Metadata/Items/Amulets/Talismans/Talisman3_6_3']
# Leather Belt ['Metadata/Items/Belts/Belt3', 'Metadata/Items/Belts/BeltRoyale1']
# Heavy Belt ['Metadata/Items/Belts/Belt4', 'Metadata/Items/Belts/BeltRoyale2']
# Cloth Belt ['Metadata/Items/Belts/Belt5', 'Metadata/Items/Belts/BeltRoyale3']
# Two-Toned Boots ['Metadata/Items/Armours/Boots/BootsAtlas1', 'Metadata/Items/Armours/Boots/BootsAtlas2', 'Metadata/Items/Armours/Boots/BootsAtlas3']
# Small Life Flask ['Metadata/Items/Flasks/FlaskLife1', 'Metadata/Items/Flasks/FlaskLife1Royale']
# Medium Life Flask ['Metadata/Items/Flasks/FlaskLife2', 'Metadata/Items/Flasks/FlaskLife2Royale']
# Large Life Flask ['Metadata/Items/Flasks/FlaskLife3', 'Metadata/Items/Flasks/FlaskLife3Royale']
# Serrated Arrow Quiver ['Metadata/Items/Quivers/Quiver6', 'Metadata/Items/Quivers/QuiverNew1', 'Metadata/Items/Quivers/QuiverDescent']
# Two-Point Arrow Quiver ['Metadata/Items/Quivers/Quiver7', 'Metadata/Items/Quivers/QuiverNew7']
# Sharktooth Arrow Quiver ['Metadata/Items/Quivers/Quiver8', 'Metadata/Items/Quivers/QuiverNew3']
# Blunt Arrow Quiver ['Metadata/Items/Quivers/Quiver9', 'Metadata/Items/Quivers/QuiverNew6']
# Fire Arrow Quiver ['Metadata/Items/Quivers/Quiver10', 'Metadata/Items/Quivers/QuiverNew2']
# Broadhead Arrow Quiver ['Metadata/Items/Quivers/Quiver11', 'Metadata/Items/Quivers/QuiverNew10']
# Penetrating Arrow Quiver ['Metadata/Items/Quivers/Quiver12', 'Metadata/Items/Quivers/QuiverNew5']
# Spike-Point Arrow Quiver ['Metadata/Items/Quivers/Quiver13', 'Metadata/Items/Quivers/QuiverNew8']
# Shaper's Orb (Tier 8) ['Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier8_1', 'Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier8_2']
# Shaper's Orb (Tier 9) ['Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier9_1', 'Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier9_2', 'Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier9_3']
# Shaper's Orb (Tier 10) ['Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier10_1', 'Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier10_2', 'Metadata/Items/QuestItems/MapUpgrades/MapUpgradeTier10_3']
# Book of Skill ['Metadata/Items/QuestItems/SkillBooks/Book-a1q6', 'Metadata/Items/QuestItems/SkillBooks/Book-a1q7', 'Metadata/Items/QuestItems/SkillBooks/Book-a1q9', 'Metadata/Items/QuestItems/SkillBooks/Book-a2q5', 'Metadata/Items/QuestItems/SkillBooks/Book-a3q9', 'Metadata/Items/QuestItems/SkillBooks/Book-a3q11v0', 'Metadata/Items/QuestItems/SkillBooks/Book-a3q11v1', 'Metadata/Items/QuestItems/SkillBooks/Book-a3q11v2', 'Metadata/Items/QuestItems/SkillBooks/Descent2_1', 'Metadata/Items/QuestItems/SkillBooks/Descent2_2', 'Metadata/Items/QuestItems/SkillBooks/Descent2_3', 'Metadata/Items/QuestItems/SkillBooks/Descent2_4', 'Metadata/Items/QuestItems/Act4/Book-a4q6', 'Metadata/Items/QuestItems/Act5/Book-a5q3', 'Metadata/Items/QuestItems/Act5/Book-a5q7', 'Metadata/Items/QuestItems/Act6/Book-a6q3', 'Metadata/Items/QuestItems/Act6/Book-a6q6', 'Metadata/Items/QuestItems/Act6/Book-a6q7', 'Metadata/Items/QuestItems/Act7/Book-a7q1', 'Metadata/Items/QuestItems/Act7/Book-a7q3', 'Metadata/Items/QuestItems/Act7/Book-a7q6', 'Metadata/Items/QuestItems/Act7/Book-a7q9', 'Metadata/Items/QuestItems/Act8/Book-a8q4', 'Metadata/Items/QuestItems/Act8/Book-a8q6', 'Metadata/Items/QuestItems/Act8/Book-a8q7', 'Metadata/Items/QuestItems/Act9/Book-a9q2', 'Metadata/Items/QuestItems/Act9/Book-a9q5', 'Metadata/Items/QuestItems/Act10/Book-a10q3', 'Metadata/Items/QuestItems/Act10/Book-a10q6']
# Book of Regrets ['Metadata/Items/QuestItems/SkillBooks/Book-a1q8', 'Metadata/Items/QuestItems/Act6/Book-a6q4', 'Metadata/Items/QuestItems/Act9/Book-a9q4', 'Metadata/Items/QuestItems/Act10/Book-a10q4']
# Book of Reform ['Metadata/Items/QuestItems/SkillBooks/BanditRespecEramir', 'Metadata/Items/QuestItems/SkillBooks/BanditRespecAlira', 'Metadata/Items/QuestItems/SkillBooks/BanditRespecOak', 'Metadata/Items/QuestItems/SkillBooks/BanditRespecKraityn']
# Atlas Book of Skill ['Metadata/Items/QuestItems/SkillBooks/AtlasSkillBookElder', 'Metadata/Items/QuestItems/SkillBooks/AtlasSkillBookMaven', 'Metadata/Items/QuestItems/SkillBooks/AtlasSkillBookTangle', 'Metadata/Items/QuestItems/SkillBooks/AtlasSkillBookCleansingFire', 'Metadata/Items/QuestItems/SkillBooks/AtlasSkillBookInfiniteHunger', 'Metadata/Items/QuestItems/SkillBooks/AtlasSkillBookBlackStar']
# Golden Page ['Metadata/Items/QuestItems/GoldenPages/Page1', 'Metadata/Items/QuestItems/GoldenPages/Page2', 'Metadata/Items/QuestItems/GoldenPages/Page3', 'Metadata/Items/QuestItems/GoldenPages/Page4']
# Firefly ['Metadata/Items/QuestItems/Act7/Firefly1', 'Metadata/Items/QuestItems/Act7/Firefly2', 'Metadata/Items/QuestItems/Act7/Firefly3', 'Metadata/Items/QuestItems/Act7/Firefly4', 'Metadata/Items/QuestItems/Act7/Firefly5', 'Metadata/Items/QuestItems/Act7/Firefly6', 'Metadata/Items/QuestItems/Act7/Firefly7']
# Spectral Shield Throw ['Metadata/Items/Gems/SkillGemThrownShieldProjectile', 'Metadata/Items/Gems/SkillGemThrownShieldProjectileRoyale']
# Fireball ['Metadata/Items/Gems/SkillGemFireball', 'Metadata/Items/Gems/SkillGemFireballRoyale']
# Ice Nova ['Metadata/Items/Gems/SkillGemIceNova', 'Metadata/Items/Gems/SkillGemIceNovaRoyale']
# Leap Slam ['Metadata/Items/Gems/SkillGemLeapSlam', 'Metadata/Items/Gems/SkillGemLeapSlamRoyale']
# Charged Dash ['Metadata/Items/Gems/SkillGemChargedDash', 'Metadata/Items/Gems/SkillGemChargedDashRoyale']
# Blade Flurry ['Metadata/Items/Gems/SkillGemChargedAttack', 'Metadata/Items/Gems/SkillGemChargedAttackRoyale']
# Sweep ['Metadata/Items/Gems/SkillGemSweep', 'Metadata/Items/Gems/SkillGemSweepRoyale']
# Ground Slam ['Metadata/Items/Gems/SkillGemGroundSlam', 'Metadata/Items/Gems/SkillGemGroundSlamRoyale']
# Cleave ['Metadata/Items/Gems/SkillGemCleave', 'Metadata/Items/Gems/SkillGemCleaveRoyale']
# Shield Charge ['Metadata/Items/Gems/SkillGemShieldCharge', 'Metadata/Items/Gems/SkillGemShieldChargeRoyale']
# Enduring Cry ['Metadata/Items/Gems/SkillGemEnduringCry', 'Metadata/Items/Gems/SkillGemEnduringCryRoyale']
# Lacerate ['Metadata/Items/Gems/SkillGemLacerate', 'Metadata/Items/Gems/SkillGemLacerateRoyale']
# Elemental Hit ['Metadata/Items/Gems/SkillGemElementalHit', 'Metadata/Items/Gems/SkillGemElementalHitRoyale']
# Dual Strike ['Metadata/Items/Gems/SkillGemDualStrike', 'Metadata/Items/Gems/SkillGemDualStrikeRoyale']
# Whirling Blades ['Metadata/Items/Gems/SkillGemWhirlingBlades', 'Metadata/Items/Gems/SkillGemWhirlingBladesRoyale']
# Cold Snap ['Metadata/Items/Gems/SkillGemColdSnap', 'Metadata/Items/Gems/SkillGemColdSnapRoyale']
# Detonate Dead ['Metadata/Items/Gems/SkillGemDetonateDead', 'Metadata/Items/Gems/SkillGemDetonateDeadRoyale']
# Unearth ['Metadata/Items/Gems/SkillGemBoneLance', 'Metadata/Items/Gems/SkillGemBoneLanceRoyale']
# Caustic Arrow ['Metadata/Items/Gems/SkillGemPoisonArrow', 'Metadata/Items/Gems/SkillGemPoisonArrowRoyale']
# Creeping Frost ['Metadata/Items/Gems/SkillGemArcticBreath', 'Metadata/Items/Gems/SkillGemArcticBreathRoyale']
# Ice Shot ['Metadata/Items/Gems/SkillGemIceShot', 'Metadata/Items/Gems/SkillGemIceShotRoyale']
# Faster Attacks Support ['Metadata/Items/Gems/SupportGemFasterAttack', 'Metadata/Items/Gems/SupportGemFasterAttackRoyale']
# Lesser Multiple Projectiles Support ['Metadata/Items/Gems/SupportGemLesserMultipleProjectiles', 'Metadata/Items/Gems/SupportGemLesserMultipleProjectilesRoyale']
# Faster Projectiles Support ['Metadata/Items/Gems/SupportGemFasterProjectiles', 'Metadata/Items/Gems/SupportGemFasterProjectilesRoyale']
# Added Cold Damage Support ['Metadata/Items/Gems/SupportGemAddedColdDamage', 'Metadata/Items/Gems/SupportGemAddedColdDamageRoyale']
# Increased Area of Effect Support ['Metadata/Items/Gems/SupportGemIncreasedAreaOfEffect', 'Metadata/Items/Gems/SupportGemIncreasedAreaOfEffectRoyale']
# Added Lightning Damage Support ['Metadata/Items/Gems/SupportGemAddedLightningDamage', 'Metadata/Items/Gems/SupportGemAddedLightningDamageRoyale']
# Increased Critical Strikes Support ['Metadata/Items/Gems/SupportGemIncreasedCriticalStrikes', 'Metadata/Items/Gems/SupportGemIncreasedCriticalStrikesRoyale']
# Knockback Support ['Metadata/Items/Gems/SupportGemKnockback', 'Metadata/Items/Gems/SupportGemKnockbackRoyale']
# Stun Support ['Metadata/Items/Gems/SupportGemStun', 'Metadata/Items/Gems/SupportGemStunRoyale']
# Ice Spear ['Metadata/Items/Gems/SkillGemIceSpear', 'Metadata/Items/Gems/SkillGemIceSpearRoyale']
# Trap Support ['Metadata/Items/Gems/SupportGemTrap', 'Metadata/Items/Gems/SupportGemTrapRoyale']
# Infernal Blow ['Metadata/Items/Gems/SkillGemInfernalBlow', 'Metadata/Items/Gems/SkillGemInfernalBlowRoyale']
# Glacial Hammer ['Metadata/Items/Gems/SkillGemGlacialHammer', 'Metadata/Items/Gems/SkillGemGlacialHammerRoyale']
# Freezing Pulse ['Metadata/Items/Gems/SkillGemFreezingPulse', 'Metadata/Items/Gems/SkillGemFreezingPulseRoyale']
# Shock Nova ['Metadata/Items/Gems/SkillGemShockNova', 'Metadata/Items/Gems/SkillGemShockNovaRoyale']
# Viper Strike ['Metadata/Items/Gems/SkillGemViperStrike', 'Metadata/Items/Gems/SkillGemViperStrikeRoyale']
# Phase Run ['Metadata/Items/Gems/SkillGemNewPhaseRun', 'Metadata/Items/Gems/SkillGemPhaseRun', 'Metadata/Items/Gems/SkillGemPhaseRunRoyale']
# Faster Casting Support ['Metadata/Items/Gems/SupportGemFasterCast', 'Metadata/Items/Gems/SupportGemFasterCastRoyale']
# Explosive Arrow ['Metadata/Items/Gems/SkillGemExplosiveArrow', 'Metadata/Items/Gems/SkillGemExplosiveArrowRoyale']
# Elemental Weakness ['Metadata/Items/Gems/SkillGemElementalWeakness', 'Metadata/Items/Gems/SkillGemElementalWeaknessRoyale']
# Warlord's Mark ['Metadata/Items/Gems/SkillGemWarlordsMark', 'Metadata/Items/Gems/SkillGemWarlordsMarkRoyale']
# Assassin's Mark ['Metadata/Items/Gems/SkillGemCriticalWeakness', 'Metadata/Items/Gems/SkillGemCriticalWeaknessRoyale']
# Despair ['Metadata/Items/Gems/SkillGemVulnerability', 'Metadata/Items/Gems/SkillGemVulnerabilityRoyale']
# Lightning Warp ['Metadata/Items/Gems/SkillGemLightningWarp', 'Metadata/Items/Gems/SkillGemLightningWarpRoyale']
# Summon Skeletons ['Metadata/Items/Gems/SkillGemSummonSkeletons', 'Metadata/Items/Gems/SkillGemSummonSkeletonsRoyale']
# Heavy Strike ['Metadata/Items/Gems/SkillGemHeavyStrike', 'Metadata/Items/Gems/SkillGemHeavyStrikeRoyale']
# Dominating Blow ['Metadata/Items/Gems/SkillGemDominatingBlow', 'Metadata/Items/Gems/SkillGemDominatingBlowRoyale']
# Rain of Arrows ['Metadata/Items/Gems/SkillGemRainOfArrows', 'Metadata/Items/Gems/SkillGemRainOfArrowsRoyale']
# Concentrated Effect Support ['Metadata/Items/Gems/SupportGemConcentratedEffect', 'Metadata/Items/Gems/SupportGemConcentratedEffectRoyale']
# Firestorm ['Metadata/Items/Gems/SkillGemFirestorm', 'Metadata/Items/Gems/SkillGemFirestormRoyale']
# Puncture ['Metadata/Items/Gems/SkillGemPuncture', 'Metadata/Items/Gems/SkillGemPunctureRoyale']
# Lightning Arrow ['Metadata/Items/Gems/SkillGemLightningArrow', 'Metadata/Items/Gems/SkillGemLightningArrowRoyale']
# Vitality ['Metadata/Items/Gems/SkillGemVitality', 'Metadata/Items/Gems/SkillGemVitalityRoyale']
# Burning Arrow ['Metadata/Items/Gems/SkillGemBurningArrow', 'Metadata/Items/Gems/SkillGemBurningArrowRoyale']
# Clarity ['Metadata/Items/Gems/SkillGemClarity', 'Metadata/Items/Gems/SkillGemClarityRoyale']
# Point Blank Support ['Metadata/Items/Gems/SupportGemPointBlank', 'Metadata/Items/Gems/SupportGemPointBlankRoyale']
# Spell Totem Support ['Metadata/Items/Gems/SupportGemSpellTotem', 'Metadata/Items/Gems/SupportGemSpellTotemRoyale']
# Shockwave Totem ['Metadata/Items/Gems/SkillGemShockwaveTotem', 'Metadata/Items/Gems/SkillGemShockwaveTotemRoyale']
# Rejuvenation Totem ['Metadata/Items/Gems/SkillGemRejuvenationTotem', 'Metadata/Items/Gems/SkillGemRejuvenationTotemRoyale']
# Bear Trap ['Metadata/Items/Gems/SkillGemBearTrap', 'Metadata/Items/Gems/SkillGemBearTrapRoyale']
# Fire Trap ['Metadata/Items/Gems/SkillGemFireTrap', 'Metadata/Items/Gems/SkillGemFireTrapRoyale']
# Ethereal Knives ['Metadata/Items/Gems/SkillGemEtherealKnives', 'Metadata/Items/Gems/SkillGemEtherealKnivesRoyale']
# Arctic Armour ['Metadata/Items/Gems/SkillGemNewArcticArmour', 'Metadata/Items/Gems/SkillGemArcticArmour']
# Holy Flame Totem ['Metadata/Items/Gems/SkillGemFlameTotem', 'Metadata/Items/Gems/SkillGemFlameTotemRoyale']
# Blind Support ['Metadata/Items/Gems/SupportGemBlind', 'Metadata/Items/Gems/SupportGemBlindRoyale']
# Ballista Totem Support ['Metadata/Items/Gems/SupportGemRangedAttackTotem', 'Metadata/Items/Gems/SupportGemRangedAttackTotemRoyale']
# Incinerate ['Metadata/Items/Gems/SkillGemIncinerate', 'Metadata/Items/Gems/SkillGemIncinerateRoyale']
# Cyclone ['Metadata/Items/Gems/SkillGemCyclone', 'Metadata/Items/Gems/SkillGemCycloneRoyale']
# Multistrike Support ['Metadata/Items/Gems/SupportGemMultistrike', 'Metadata/Items/Gems/SupportGemMultistrikeRoyale']
# Spell Echo Support ['Metadata/Items/Gems/SupportGemMulticast', 'Metadata/Items/Gems/SupportGemMulticastRoyale']
# Melee Splash Support ['Metadata/Items/Gems/SupportGemMeleeSplash', 'Metadata/Items/Gems/SupportGemMeleeSplashRoyale']
# Searing Bond ['Metadata/Items/Gems/SkillGemSearingBond', 'Metadata/Items/Gems/SkillGemSearingBondRoyale']
# Lightning Trap ['Metadata/Items/Gems/SkillGemLightningTrap', 'Metadata/Items/Gems/SkillGemLightningTrapRoyale']
# Smoke Mine ['Metadata/Items/Gems/SkillGemSmokeMine', 'Metadata/Items/Gems/SkillGemSmokeMineRoyale']
# Spectral Throw ['Metadata/Items/Gems/SkillGemThrownWeapon', 'Metadata/Items/Gems/SkillGemThrownWeaponRoyale']
# Less Duration Support ['Metadata/Items/Gems/SupportGemReducedDuration', 'Metadata/Items/Gems/SupportGemReducedDurationRoyale']
# Cast on Death Support ['Metadata/Items/Gems/SupportGemCastOnDeath', 'Metadata/Items/Gems/SupportGemCastOnDeathRoyale']
# Storm Call ['Metadata/Items/Gems/SkillGemStormCall', 'Metadata/Items/Gems/SkillGemStormCallRoyale']
# Ball Lightning ['Metadata/Items/Gems/SkillGemBallLightning', 'Metadata/Items/Gems/SkillGemBallLightningRoyale']
# Summon Raging Spirit ['Metadata/Items/Gems/SkillGemSummonRagingSpirit', 'Metadata/Items/Gems/SkillGemSummonRagingSpiritRoyale']
# Desecrate ['Metadata/Items/Gems/SkillGemDesecrate', 'Metadata/Items/Gems/SkillGemDesecrateRoyale']
# Glacial Cascade ['Metadata/Items/Gems/SkillGemGlacialCascade', 'Metadata/Items/Gems/SkillGemGlacialCascadeRoyale']
# Convocation ['Metadata/Items/Gems/SkillGemConvocation', 'Metadata/Items/Gems/SkillGemConvocationNew']
# Molten Strike ['Metadata/Items/Gems/SkillGemMoltenStrike', 'Metadata/Items/Gems/SkillGemMoltenStrikeRoyale']
# Poacher's Mark ['Metadata/Items/Gems/SkillGemPoachersMark', 'Metadata/Items/Gems/SkillGemPoachersMarkRoyale']
# Lightning Tendrils ['Metadata/Items/Gems/SkillGemLightningTendrils', 'Metadata/Items/Gems/SkillGemLightningTendrilsChannelled', 'Metadata/Items/Gems/SkillGemLightningTendrilsRoyale']
# Blink Arrow ['Metadata/Items/Gems/SkillGemBlinkArrow', 'Metadata/Items/Gems/SkillGemBlinkArrowRoyale']
# Blasphemy Support ['Metadata/Items/Gems/SupportGemBlasphemy', 'Metadata/Items/Gems/SupportGemBlasphemyRoyale']
# Ice Crash ['Metadata/Items/Gems/SkillGemIceCrash', 'Metadata/Items/Gems/SkillGemIceCrashRoyale']
# Flame Dash ['Metadata/Items/Gems/SkillGemFlameDash', 'Metadata/Items/Gems/SkillGemFlameDashRoyale']
# Frost Blades ['Metadata/Items/Gems/SkillGemFrostBlades', 'Metadata/Items/Gems/SkillGemFrostBladesRoyale']
# Fortify Support ['Metadata/Items/Gems/SupportGemFortify', 'Metadata/Items/Gems/SupportGemFortifyRoyale']
# Rolling Magma ['Metadata/Items/Gems/SkillGemMagmaOrb', 'Metadata/Items/Gems/SkillGemMagmaOrbRoyale']
# Ice Trap ['Metadata/Items/Gems/SkillGemIceTrap', 'Metadata/Items/Gems/SkillGemIceTrapRoyale']
# Wild Strike ['Metadata/Items/Gems/SkillGemWildStrike', 'Metadata/Items/Gems/SkillGemWildStrikeRoyale']
# Galvanic Arrow ['Metadata/Items/Gems/SkillGemShrapnelShot', 'Metadata/Items/Gems/SkillGemShrapnelShotRoyale']
# Blast Rain ['Metadata/Items/Gems/SkillGemBlastRain', 'Metadata/Items/Gems/SkillGemBlastRainRoyale']
# Bladefall ['Metadata/Items/Gems/SkillGemBladefall', 'Metadata/Items/Gems/SkillGemBladefallRoyale']
# Siege Ballista ['Metadata/Items/Gems/SkillGemSiegeBallista', 'Metadata/Items/Gems/SkillGemSiegeBallistaRoyale']
# Blade Vortex ['Metadata/Items/Gems/SkillGemBladeVortex', 'Metadata/Items/Gems/SkillGemBladeVortexRoyale']
# Frost Bomb ['Metadata/Items/Gems/SkillGemFrostBomb', 'Metadata/Items/Gems/SkillGemFrostBombRoyale']
# Earthquake ['Metadata/Items/Gems/SkillGemEarthquake', 'Metadata/Items/Gems/SkillGemEarthquakeRoyale']
# Blight ['Metadata/Items/Gems/SkillGemBlight', 'Metadata/Items/Gems/SkillGemBlightRoyale']
# Essence Drain ['Metadata/Items/Gems/SkillGemEssenceDrain', 'Metadata/Items/Gems/SkillGemEssenceDrainRoyale']
# Sunder ['Metadata/Items/Gems/SkillGemSunder', 'Metadata/Items/Gems/SkillGemSunderRoyale']
# Frostbolt ['Metadata/Items/Gems/SkillGemFrostBolt', 'Metadata/Items/Gems/SkillGemFrostBoltRoyale']
# Vortex ['Metadata/Items/Gems/SkillGemFrostBoltNova', 'Metadata/Items/Gems/SkillGemFrostBoltNovaRoyale']
# Ancestral Protector ['Metadata/Items/Gems/SkillGemMeleeTotem', 'Metadata/Items/Gems/SkillGemMeleeTotemRoyale']
# Ancestral Warchief ['Metadata/Items/Gems/SkillGemAncestralWarchief', 'Metadata/Items/Gems/SkillGemAncestralWarchiefRoyale']
# Advanced Traps Support ['Metadata/Items/Gems/SupportGemTrapCooldown', 'Metadata/Items/Gems/SupportGemTrapCooldownRoyale']
# Cast while Channelling Support ['Metadata/Items/Gems/SupportGemCastWhileChannelling', 'Metadata/Items/Gems/SupportGemCastWhileChannellingRoyale']
# Chance to Bleed Support ['Metadata/Items/Gems/SupportGemChanceToBleed', 'Metadata/Items/Gems/SupportGemChanceToBleedRoyale']
# Maim Support ['Metadata/Items/Gems/SupportGemMaim', 'Metadata/Items/Gems/SupportGemMaimRoyale']
# Dark Pact ['Metadata/Items/Gems/SkillGemDarkPact', 'Metadata/Items/Gems/SkillGemDarkPactRoyale']
# Cremation ['Metadata/Items/Gems/SkillGemCorpseEruption', 'Metadata/Items/Gems/SkillGemCorpseEruptionRoyale']
# Volley Support ['Metadata/Items/Gems/SupportGemParallelProjectiles', 'Metadata/Items/Gems/SupportGemParallelProjectilesRoyale']
# Spell Cascade Support ['Metadata/Items/Gems/SupportGemSpellCascade', 'Metadata/Items/Gems/SupportGemSpellCascadeRoyale']
# Ancestral Call Support ['Metadata/Items/Gems/SupportGemSpiritStrike', 'Metadata/Items/Gems/SupportGemSpiritStrikeRoyale']
# Summon Phantasm Support ['Metadata/Items/Gems/SupportGemSummonGhostOnKill', 'Metadata/Items/Gems/SupportGemSummonGhostOnKillRoyale']
# Vulnerability ['Metadata/Items/Gems/SkillGemNewVulnerability', 'Metadata/Items/Gems/SkillGemNewVulnerabilityRoyale']
# Siphoning Trap ['Metadata/Items/Gems/SkillGemIceSiphonTrap', 'Metadata/Items/Gems/SkillGemIceSiphonTrapRoyale']
# Flamethrower Trap ['Metadata/Items/Gems/SkillGemFlamethrowerTrap', 'Metadata/Items/Gems/SkillGemFlamethrowerTrapRoyale']
# Lightning Spire Trap ['Metadata/Items/Gems/SkillGemLightningTowerTrap', 'Metadata/Items/Gems/SkillGemLightningTowerTrapRoyale']
# Smite ['Metadata/Items/Gems/SkillGemSmite', 'Metadata/Items/Gems/SkillGemSmiteRoyale']
# Scourge Arrow ['Metadata/Items/Gems/SkillGemScourgeArrow', 'Metadata/Items/Gems/SkillGemScourgeArrowRoyale']
# Toxic Rain ['Metadata/Items/Gems/SkillGemToxicRain', 'Metadata/Items/Gems/SkillGemToxicRainRoyale']
# Shattering Steel ['Metadata/Items/Gems/SkillGemShatteringSteel', 'Metadata/Items/Gems/SkillGemShatteringSteelRoyale']
# Multiple Totems Support ['Metadata/Items/Gems/SupportGemMultiTotem', 'Metadata/Items/Gems/SupportGemMultiTotemRoyale']
# Purifying Flame ['Metadata/Items/Gems/SkillGemSanctify', 'Metadata/Items/Gems/SkillGemSanctifyRoyale']
# Divine Ire ['Metadata/Items/Gems/SkillGemDivineTempest', 'Metadata/Items/Gems/SkillGemDivineTempestRoyale']
# Wave of Conviction ['Metadata/Items/Gems/SkillGemPurge', 'Metadata/Items/Gems/SkillGemPurgeRoyale']
# Unleash Support ['Metadata/Items/Gems/SupportGemHandcastAnticipation', 'Metadata/Items/Gems/SupportGemHandcastAnticipationRoyale']
# Dash ['Metadata/Items/Gems/SkillGemDash', 'Metadata/Items/Gems/SkillGemDashRoyale']
# Bladestorm ['Metadata/Items/Gems/SkillGemBladestorm', 'Metadata/Items/Gems/SkillGemBladestormRoyale']
# Blood and Sand ['Metadata/Items/Gems/SkillGemBloodAndSand', 'Metadata/Items/Gems/SkillGemBloodAndSandRoyale']
# Chain Hook ['Metadata/Items/Gems/SkillGemChainHook', 'Metadata/Items/Gems/SkillGemChainHookRoyale']
# Frostblink ['Metadata/Items/Gems/SkillGemFrostblink', 'Metadata/Items/Gems/SkillGemFrostblinkRoyale']
# Precision ['Metadata/Items/Gems/SkillGemPrecision', 'Metadata/Items/Gems/SkillGemPrecisionRoyale']
# Rage Support ['Metadata/Items/Gems/SupportGemRage', 'Metadata/Items/Gems/SupportGemRageRoyale']
# Cobra Lash ['Metadata/Items/Gems/SkillGemCobraLash', 'Metadata/Items/Gems/SkillGemCobraLashRoyale']
# Venom Gyre ['Metadata/Items/Gems/SkillGemVenomGyre', 'Metadata/Items/Gems/SkillGemVenomGyreRoyale']
# Arrow Nova Support ['Metadata/Items/Gems/SupportGemArrowNova', 'Metadata/Items/Gems/SupportGemArrowNovaRoyale']
# Ensnaring Arrow ['Metadata/Items/Gems/SkillGemEnsnaringArrow', 'Metadata/Items/Gems/SkillGemEnsnaringArrowRoyale']
# Artillery Ballista ['Metadata/Items/Gems/SkillGemArtilleryBallista', 'Metadata/Items/Gems/SkillGemArtilleryBallistaRoyale']
# Blade Blast ['Metadata/Items/Gems/SkillGemBladeBlast', 'Metadata/Items/Gems/SkillGemBladeBlastRoyale']
# Second Wind Support ['Metadata/Items/Gems/SupportGemSecondWind', 'Metadata/Items/Gems/SupportGemSecondWindRoyale']
# Fist of War Support ['Metadata/Items/Gems/SupportGemFistOfWar', 'Metadata/Items/Gems/SupportGemFistOfWarRoyale']
# General's Cry ['Metadata/Items/Gems/SkillGemGeneralsCry', 'Metadata/Items/Gems/SkillGemGeneralsCryRoyale']
# Blazing Salvo ['Metadata/Items/Gems/SkillGemBlazingSalvo', 'Metadata/Items/Gems/SkillGemBlazingSalvoRoyale']
# Void Sphere ['Metadata/Items/Gems/SkillGemVoidSphere', 'Metadata/Items/Gems/SkillGemVoidSphereRoyale']
# Impending Doom Support ['Metadata/Items/Gems/SupportGemImpendingDoom', 'Metadata/Items/Gems/SupportGemImpendingDoomRoyale']
# Hydrosphere ['Metadata/Items/Gems/SkillGemHydrosphere', 'Metadata/Items/Gems/SkillGemHydrosphereRoyale']
# Reap ['Metadata/Items/Gems/SkillGemBloodreap', 'Metadata/Items/Gems/SkillGemBloodreapRoyale']
# Lifetap Support ['Metadata/Items/Gems/SupportGemLifetap', 'Metadata/Items/Gems/SupportGemLifetapRoyale']
# Energy Blade ['Metadata/Items/Gems/SkillGemEnergyBlade', 'Metadata/Items/Weapons/OneHandWeapons/OneHandSwords/StormBladeOneHand', 'Metadata/Items/Weapons/TwoHandWeapons/TwoHandSwords/StormBladeTwoHand']
# Cursed Crypt Map ['Metadata/Items/Maps/MapTier1_1', 'Metadata/Items/Maps/Map2Tier1_1', 'Metadata/Items/Maps/MapAtlasCrypt', 'Metadata/Items/Maps/MapWorldsCursedCrypt']
# Dungeon Map ['Metadata/Items/Maps/MapTier1_2', 'Metadata/Items/Maps/Map2Tier1_2', 'Metadata/Items/Maps/MapAtlasDungeon', 'Metadata/Items/Maps/MapWorldsDungeon']
# Grotto Map ['Metadata/Items/Maps/MapTier1_3', 'Metadata/Items/Maps/Map2Tier1_3', 'Metadata/Items/Maps/MapAtlasGrotto', 'Metadata/Items/Maps/MapWorldsGrotto']
# Overgrown Ruin Map ['Metadata/Items/Maps/MapTier1_4', 'Metadata/Items/Maps/Map2Tier12_2', 'Metadata/Items/Maps/MapAtlasOvergrownRuin', 'Metadata/Items/Maps/MapWorldsOvergrownRuin']
# Dunes Map ['Metadata/Items/Maps/MapTier1_5', 'Metadata/Items/Maps/Map2Tier1_4', 'Metadata/Items/Maps/MapAtlasDunes', 'Metadata/Items/Maps/MapWorldsDunes']
# Arid Lake Map ['Metadata/Items/Maps/MapTier1_6', 'Metadata/Items/Maps/Map2Tier9_2', 'Metadata/Items/Maps/MapAtlasAridLake', 'Metadata/Items/Maps/MapWorldsAridLake']
# Tropical Island Map ['Metadata/Items/Maps/MapTier1_7', 'Metadata/Items/Maps/Map2Tier1_6', 'Metadata/Items/Maps/MapAtlasTropicalIsland', 'Metadata/Items/Maps/MapWorldsTropicalIsland']
# Orchard Map ['Metadata/Items/Maps/MapTier1_8', 'Metadata/Items/Maps/Map2Tier8_5', 'Metadata/Items/Maps/MapAtlasOrchard', 'Metadata/Items/Maps/MapWorldsOrchard']
# Wharf Map ['Metadata/Items/Maps/MapTier2_1', 'Metadata/Items/Maps/Map2Tier2_7', 'Metadata/Items/Maps/MapAtlasWharf', 'Metadata/Items/Maps/MapWorldsWharf']
# Arsenal Map ['Metadata/Items/Maps/MapTier2_2', 'Metadata/Items/Maps/Map2Tier12_4', 'Metadata/Items/Maps/MapAtlasArsenal', 'Metadata/Items/Maps/MapWorldsArsenal']
# Thicket Map ['Metadata/Items/Maps/MapTier2_3', 'Metadata/Items/Maps/Map2Tier2_3', 'Metadata/Items/Maps/MapAtlasThicket', 'Metadata/Items/Maps/MapWorldsThicket']
# Atoll Map ['Metadata/Items/Maps/MapTier2_4', 'Metadata/Items/Maps/Map2Tier2_4', 'Metadata/Items/Maps/MapAtlasAtoll', 'Metadata/Items/Maps/MapWorldsAtoll']
# Cemetery Map ['Metadata/Items/Maps/MapTier2_5', 'Metadata/Items/Maps/Map2Tier2_5', 'Metadata/Items/Maps/MapAtlasCemetery', 'Metadata/Items/Maps/MapWorldsCemetery']
# Toxic Sewer Map ['Metadata/Items/Maps/MapTier2_6', 'Metadata/Items/Maps/Map2Tier2_1', 'Metadata/Items/Maps/MapAtlasSewer', 'Metadata/Items/Maps/MapWorldsToxicSewer']
# Arcade Map ['Metadata/Items/Maps/MapTier2_7', 'Metadata/Items/Maps/Map2Tier2_6', 'Metadata/Items/Maps/MapAtlasArcade', 'Metadata/Items/Maps/MapWorldsArcade']
# Ghetto Map ['Metadata/Items/Maps/MapTier3_1', 'Metadata/Items/Maps/Map2Tier3_1', 'Metadata/Items/Maps/MapAtlasGhetto', 'Metadata/Items/Maps/MapWorldsGhetto']
# Spider Lair Map ['Metadata/Items/Maps/MapTier3_2', 'Metadata/Items/Maps/Map2Tier3_2', 'Metadata/Items/Maps/MapAtlasSpiderLair', 'Metadata/Items/Maps/MapWorldsSpiderLair']
# Vaal Pyramid Map ['Metadata/Items/Maps/MapTier3_3', 'Metadata/Items/Maps/Map2Tier3_3', 'Metadata/Items/Maps/MapAtlasVaalPyramid', 'Metadata/Items/Maps/MapWorldsVaalPyramid']
# Reef Map ['Metadata/Items/Maps/MapTier3_4', 'Metadata/Items/Maps/Map2Tier3_4', 'Metadata/Items/Maps/MapAtlasReef', 'Metadata/Items/Maps/MapWorldsReef']
# Fungal Hollow Map ['Metadata/Items/Maps/MapTier3_5', 'Metadata/Items/Maps/Map2Tier11_4', 'Metadata/Items/Maps/MapAtlasSprings', 'Metadata/Items/Maps/MapWorldsSprings']
# Mud Geyser Map ['Metadata/Items/Maps/MapTier3_6', 'Metadata/Items/Maps/Map2Tier3_6', 'Metadata/Items/Maps/MapAtlasMudGeyser', 'Metadata/Items/Maps/MapWorldsMudGeyser']
# Museum Map ['Metadata/Items/Maps/MapTier3_7', 'Metadata/Items/Maps/Map2Tier3_7', 'Metadata/Items/Maps/MapAtlasMuseum', 'Metadata/Items/Maps/MapWorldsMuseum']
# Bone Crypt Map ['Metadata/Items/Maps/MapTier4_1', 'Metadata/Items/Maps/Map2Tier6_6', 'Metadata/Items/Maps/MapAtlasCatacomb', 'Metadata/Items/Maps/MapWorldsBoneCrypt']
# Overgrown Shrine Map ['Metadata/Items/Maps/MapTier4_2', 'Metadata/Items/Maps/Map2Tier4_2', 'Metadata/Items/Maps/MapAtlasOvergrownShrine', 'Metadata/Items/Maps/MapWorldsOvergrownShrine']
# Crystal Ore Map ['Metadata/Items/Maps/MapTier4_3', 'Metadata/Items/Maps/Map2Tier4_3', 'Metadata/Items/Maps/MapAtlasCrystalOre', 'Metadata/Items/Maps/MapWorldsCrystalOre']
# Shore Map ['Metadata/Items/Maps/MapTier4_4', 'Metadata/Items/Maps/Map2Tier4_4', 'Metadata/Items/Maps/MapAtlasShore', 'Metadata/Items/Maps/MapWorldsShore']
# Spider Forest Map ['Metadata/Items/Maps/MapTier4_5', 'Metadata/Items/Maps/Map2Tier4_5', 'Metadata/Items/Maps/MapAtlasSpiderForest', 'Metadata/Items/Maps/MapWorldsSpiderForest']
# Promenade Map ['Metadata/Items/Maps/MapTier4_6', 'Metadata/Items/Maps/Map2Tier4_6', 'Metadata/Items/Maps/MapAtlasPromenade', 'Metadata/Items/Maps/MapWorldsPromenade']
# Underground River Map ['Metadata/Items/Maps/MapTier5_1', 'Metadata/Items/Maps/Map2Tier5_1', 'Metadata/Items/Maps/MapAtlasUndergroundRiver', 'Metadata/Items/Maps/MapWorldsUndergroundRiver']
# Pier Map ['Metadata/Items/Maps/MapTier5_2', 'Metadata/Items/Maps/Map2Tier5_2', 'Metadata/Items/Maps/MapAtlasPier', 'Metadata/Items/Maps/MapWorldsPier']
# Bog Map ['Metadata/Items/Maps/MapTier5_3', 'Metadata/Items/Maps/Map2Tier5_3', 'Metadata/Items/Maps/MapAtlasBog', 'Metadata/Items/Maps/MapWorldsBog']
# Graveyard Map ['Metadata/Items/Maps/MapTier5_4', 'Metadata/Items/Maps/Map2Tier5_4', 'Metadata/Items/Maps/MapAtlasGraveyard', 'Metadata/Items/Maps/MapWorldsGraveyard']
# Coves Map ['Metadata/Items/Maps/MapTier5_5', 'Metadata/Items/Maps/Map2Tier5_5', 'Metadata/Items/Maps/MapAtlasCoves', 'Metadata/Items/Maps/MapWorldsCoves']
# Villa Map ['Metadata/Items/Maps/MapTier5_6', 'Metadata/Items/Maps/Map2Tier5_6', 'Metadata/Items/Maps/MapAtlasVilla', 'Metadata/Items/Maps/MapWorldsVilla']
# Temple Map ['Metadata/Items/Maps/MapTier6_1', 'Metadata/Items/Maps/Map2Tier6_1', 'Metadata/Items/Maps/MapAtlasTemple', 'Metadata/Items/Maps/MapWorldsTemple']
# Arachnid Nest Map ['Metadata/Items/Maps/MapTier6_2', 'Metadata/Items/Maps/Map2Tier6_2', 'Metadata/Items/Maps/MapAtlasArachnidNest', 'Metadata/Items/Maps/MapWorldsArachnidNest']
# Strand Map ['Metadata/Items/Maps/MapTier6_3', 'Metadata/Items/Maps/Map2Tier6_3', 'Metadata/Items/Maps/MapAtlasStrand', 'Metadata/Items/Maps/MapWorldsStrand']
# Ashen Wood Map ['Metadata/Items/Maps/MapTier6_4', 'Metadata/Items/Maps/Map2Tier6_4', 'Metadata/Items/Maps/MapAtlasDryWoods', 'Metadata/Items/Maps/MapWorldsAshenWood']
# Colonnade Map ['Metadata/Items/Maps/MapTier6_5', 'Metadata/Items/Maps/Map2Tier6_5', 'Metadata/Items/Maps/MapAtlasColonnade', 'Metadata/Items/Maps/MapWorldsColonnade']
# Primordial Blocks Map ['Metadata/Items/Maps/MapTier7_1', 'Metadata/Items/Maps/Map2Tier7_1', 'Metadata/Items/Maps/MapAtlasTortureChamber', 'Metadata/Items/Maps/MapWorldsTortureChamber']
# Waste Pool Map ['Metadata/Items/Maps/MapTier7_2', 'Metadata/Items/Maps/Map2Tier7_2', 'Metadata/Items/Maps/MapAtlasWastePool', 'Metadata/Items/Maps/MapWorldsWastePool']
# Flooded Mine Map ['Metadata/Items/Maps/MapTier7_3', 'Metadata/Items/Maps/Map2Tier7_3', 'Metadata/Items/Maps/MapAtlasCavern', 'Metadata/Items/Maps/MapWorldsFloodedMine']
# Jungle Valley Map ['Metadata/Items/Maps/MapTier7_4', 'Metadata/Items/Maps/Map2Tier7_4', 'Metadata/Items/Maps/MapAtlasJungleValley', 'Metadata/Items/Maps/MapWorldsJungleValley']
# Gardens Map ['Metadata/Items/Maps/MapTier7_5', 'Metadata/Items/Maps/Map2Tier7_5', 'Metadata/Items/Maps/MapAtlasTerrace', 'Metadata/Items/Maps/MapWorldsGardens']
# Cells Map ['Metadata/Items/Maps/MapTier8_1', 'Metadata/Items/Maps/Map2Tier8_1', 'Metadata/Items/Maps/MapAtlasCells', 'Metadata/Items/Maps/MapWorldsCells']
# Canyon Map ['Metadata/Items/Maps/MapTier8_2', 'Metadata/Items/Maps/Map2Tier8_2', 'Metadata/Items/Maps/MapAtlasCanyon', 'Metadata/Items/Maps/MapWorldsCanyon']
# Dark Forest Map ['Metadata/Items/Maps/MapTier8_3', 'Metadata/Items/Maps/Map2Tier8_3', 'Metadata/Items/Maps/MapAtlasDarkForest', 'Metadata/Items/Maps/MapWorldsDarkForest']
# Peninsula Map ['Metadata/Items/Maps/MapTier8_4', 'Metadata/Items/Maps/Map2Tier8_4', 'Metadata/Items/Maps/MapAtlasDryPeninsula', 'Metadata/Items/Maps/MapWorldsPeninsula']
# Underground Sea Map ['Metadata/Items/Maps/MapTier9_1', 'Metadata/Items/Maps/Map2Tier9_1', 'Metadata/Items/Maps/MapAtlasUndergroundSea', 'Metadata/Items/Maps/MapWorldsUndergroundSea']
# Maze Map ['Metadata/Items/Maps/MapTier9_2', 'Metadata/Items/Maps/Map2Tier14_3', 'Metadata/Items/Maps/MapAtlasMaze', 'Metadata/Items/Maps/MapWorldsMaze']
# Glacier Map ['Metadata/Items/Maps/MapTier9_3', 'Metadata/Items/Maps/Map2Tier9_3', 'Metadata/Items/Maps/MapAtlasGorge', 'Metadata/Items/Maps/MapWorldsGorge']
# Residence Map ['Metadata/Items/Maps/MapTier9_4', 'Metadata/Items/Maps/Map2Tier9_4', 'Metadata/Items/Maps/MapAtlasResidence', 'Metadata/Items/Maps/MapWorldsResidence']
# Necropolis Map ['Metadata/Items/Maps/MapTier10_1', 'Metadata/Items/Maps/Map2Tier10_1', 'Metadata/Items/Maps/MapAtlasNecropolis', 'Metadata/Items/Maps/MapWorldsNecropolis']
# Plateau Map ['Metadata/Items/Maps/MapTier10_2', 'Metadata/Items/Maps/Map2Tier10_2', 'Metadata/Items/Maps/MapAtlasPlateau', 'Metadata/Items/Maps/MapWorldsPlateau']
# Bazaar Map ['Metadata/Items/Maps/MapTier10_3', 'Metadata/Items/Maps/Map2Tier10_3', 'Metadata/Items/Maps/MapAtlasBazaar', 'Metadata/Items/Maps/MapWorldsBazaar']
# Lava Chamber Map ['Metadata/Items/Maps/MapTier11_1', 'Metadata/Items/Maps/Map2Tier11_1', 'Metadata/Items/Maps/MapAtlasCrematorium', 'Metadata/Items/Maps/MapWorldsLavaChamber']
# Precinct Map ['Metadata/Items/Maps/MapTier11_2', 'Metadata/Items/Maps/Map2Tier11_2', 'Metadata/Items/Maps/MapAtlasPrecinct', 'Metadata/Items/Maps/MapWorldsPrecinct']
# Academy Map ['Metadata/Items/Maps/MapTier11_3', 'Metadata/Items/Maps/Map2Tier11_3', 'Metadata/Items/Maps/MapAtlasAcademy', 'Metadata/Items/Maps/MapWorldsAcademy']
# Shipyard Map ['Metadata/Items/Maps/MapTier12_1', 'Metadata/Items/Maps/Map2Tier12_1', 'Metadata/Items/Maps/MapAtlasShipyard', 'Metadata/Items/Maps/MapWorldsShipyard']
# Shrine Map ['Metadata/Items/Maps/MapTier12_2', 'Metadata/Items/Maps/Map2Tier14_2', 'Metadata/Items/Maps/MapAtlasShrine', 'Metadata/Items/Maps/MapWorldsShrine']
# Palace Map ['Metadata/Items/Maps/MapTier13_1', 'Metadata/Items/Maps/Map2Tier14_1', 'Metadata/Items/Maps/MapAtlasPalace', 'Metadata/Items/Maps/MapWorldsPalace']
# Courtyard Map ['Metadata/Items/Maps/MapTier13_2', 'Metadata/Items/Maps/Map2Tier13_2', 'Metadata/Items/Maps/MapAtlasCourtyard', 'Metadata/Items/Maps/MapWorldsCourtyard']
# Vaal Temple Map ['Metadata/Items/Maps/MapTier14_1', 'Metadata/Items/Maps/Map2Tier14_4', 'Metadata/Items/Maps/MapAtlasVaalTemple', 'Metadata/Items/Maps/MapWorldsVaalTemple']
# Pit Map ['Metadata/Items/Maps/Map2Tier1_5', 'Metadata/Items/Maps/MapAtlasPit', 'Metadata/Items/Maps/MapWorldsPit']
# Desert Map ['Metadata/Items/Maps/Map2Tier1_7', 'Metadata/Items/Maps/MapAtlasDesert', 'Metadata/Items/Maps/MapWorldsDesert']
# Channel Map ['Metadata/Items/Maps/Map2Tier2_2', 'Metadata/Items/Maps/MapAtlasChannel', 'Metadata/Items/Maps/MapWorldsChannel']
# Geode Map ['Metadata/Items/Maps/Map2Tier3_5', 'Metadata/Items/Maps/MapAtlasQuarry', 'Metadata/Items/Maps/MapWorldsGeode']
# Arena Map ['Metadata/Items/Maps/Map2Tier4_1', 'Metadata/Items/Maps/MapAtlasArena', 'Metadata/Items/Maps/MapWorldsArena']
# Phantasmagoria Map ['Metadata/Items/Maps/Map2Tier4_7', 'Metadata/Items/Maps/MapAtlasPhantasmagoria', 'Metadata/Items/Maps/MapWorldsPhantasmagoria']
# Malformation Map ['Metadata/Items/Maps/Map2Tier9_5', 'Metadata/Items/Maps/MapAtlasMalformation', 'Metadata/Items/Maps/MapWorldsMalformation']
# Volcano Map ['Metadata/Items/Maps/Map2Tier10_4', 'Metadata/Items/Maps/MapAtlasVolcano', 'Metadata/Items/Maps/MapWorldsVolcano']
# Chateau Map ['Metadata/Items/Maps/Map2Tier10_5', 'Metadata/Items/Maps/MapAtlasChateau', 'Metadata/Items/Maps/MapWorldsChateau']
# Castle Ruins Map ['Metadata/Items/Maps/Map2Tier12_3', 'Metadata/Items/Maps/MapAtlasCastleRuins', 'Metadata/Items/Maps/MapWorldsCastleRuins']
# Wasteland Map ['Metadata/Items/Maps/Map2Tier13_1', 'Metadata/Items/Maps/MapAtlasWasteland', 'Metadata/Items/Maps/MapWorldsWasteland']
# Excavation Map ['Metadata/Items/Maps/Map2Tier13_3', 'Metadata/Items/Maps/MapAtlasExcavation', 'Metadata/Items/Maps/MapWorldsExcavation']
# Waterways Map ['Metadata/Items/Maps/Map2Tier13_4', 'Metadata/Items/Maps/MapAtlasWaterways', 'Metadata/Items/Maps/MapWorldsWaterways']
# Plaza Map ['Metadata/Items/Maps/Map2Tier14_5', 'Metadata/Items/Maps/MapAtlasPlaza', 'Metadata/Items/Maps/MapWorldsPlaza']
# Core Map ['Metadata/Items/Maps/Map2Tier15_1', 'Metadata/Items/Maps/MapAtlasCore', 'Metadata/Items/Maps/MapWorldsCore']
# Caldera Map ['Metadata/Items/Maps/Map2Tier15_2', 'Metadata/Items/Maps/MapAtlasAbyss', 'Metadata/Items/Maps/MapWorldsCaldera']
# Colosseum Map ['Metadata/Items/Maps/Map2Tier15_3', 'Metadata/Items/Maps/MapAtlasColosseum', 'Metadata/Items/Maps/MapWorldsColosseum']
# Beach Map ['Metadata/Items/Maps/MapAtlasBeach', 'Metadata/Items/Maps/MapWorldsBeach']
# Factory Map ['Metadata/Items/Maps/MapAtlasFactory', 'Metadata/Items/Maps/MapWorldsFactory']
# Desert Spring Map ['Metadata/Items/Maps/MapAtlasOasis', 'Metadata/Items/Maps/MapWorldsDesertSpring']
# Marshes Map ['Metadata/Items/Maps/MapAtlasMarshes', 'Metadata/Items/Maps/MapWorldsMarshes']
# Acid Caverns Map ['Metadata/Items/Maps/MapAtlasAcidLakes', 'Metadata/Items/Maps/MapWorldsAcidLakes']
# Burial Chambers Map ['Metadata/Items/Maps/MapAtlasBurialChambers', 'Metadata/Items/Maps/MapWorldsBurialChambers']
# Mesa Map ['Metadata/Items/Maps/MapAtlasMesa', 'Metadata/Items/Maps/MapWorldsMesa']
# Primordial Pool Map ['Metadata/Items/Maps/MapAtlasPrimordialPool', 'Metadata/Items/Maps/MapWorldsPrimordialPool']
# Tower Map ['Metadata/Items/Maps/MapAtlasTower', 'Metadata/Items/Maps/MapWorldsTower']
# Racecourse Map ['Metadata/Items/Maps/MapAtlasRacecourse', 'Metadata/Items/Maps/MapWorldsRacecourse']
# Ramparts Map ['Metadata/Items/Maps/MapAtlasRamparts', 'Metadata/Items/Maps/MapWorldsRamparts']
# Ancient City Map ['Metadata/Items/Maps/MapAtlasVaalCity', 'Metadata/Items/Maps/MapWorldsAncientCity']
# Arachnid Tomb Map ['Metadata/Items/Maps/MapAtlasArachnidTomb', 'Metadata/Items/Maps/MapWorldsArachnidTomb']
# Armoury Map ['Metadata/Items/Maps/MapAtlasArmory', 'Metadata/Items/Maps/MapWorldsArmoury']
# Barrows Map ['Metadata/Items/Maps/MapAtlasBarrows', 'Metadata/Items/Maps/MapWorldsBarrows']
# Port Map ['Metadata/Items/Maps/MapAtlasQuay', 'Metadata/Items/Maps/MapWorldsPort']
# Estuary Map ['Metadata/Items/Maps/MapAtlasEstuary', 'Metadata/Items/Maps/MapWorldsEstuary']
# Ivory Temple Map ['Metadata/Items/Maps/MapAtlasIvoryTemple', 'Metadata/Items/Maps/MapWorldsIvoryTemple']
# Vault Map ['Metadata/Items/Maps/MapAtlasVault', 'Metadata/Items/Maps/MapWorldsVault']
# Lair Map ['Metadata/Items/Maps/MapAtlasLair', 'Metadata/Items/Maps/MapWorldsLair']
# Lighthouse Map ['Metadata/Items/Maps/MapAtlasBeacon', 'Metadata/Items/Maps/MapWorldsLighthouse']
# Terrace Map ['Metadata/Items/Maps/MapAtlasHighGardens', 'Metadata/Items/Maps/MapWorldsTerrace']
# Scriptorium Map ['Metadata/Items/Maps/MapAtlasScriptorium', 'Metadata/Items/Maps/MapWorldsScriptorium']
# Leyline Map ['Metadata/Items/Maps/MapAtlasSulphurWastes', 'Metadata/Items/Maps/MapWorldsLeyline']
# Mineral Pools Map ['Metadata/Items/Maps/MapAtlasMineralPools', 'Metadata/Items/Maps/MapWorldsMineralPools']
# Pit of the Chimera Map ['Metadata/Items/Maps/MapAtlasChimera', 'Metadata/Items/Maps/MapWorldsChimera']
# Lair of the Hydra Map ['Metadata/Items/Maps/MapAtlasHydra', 'Metadata/Items/Maps/MapWorldsHydra']
# Maze of the Minotaur Map ['Metadata/Items/Maps/MapAtlasMinotaur', 'Metadata/Items/Maps/MapWorldsMinotaur']
# Forge of the Phoenix Map ['Metadata/Items/Maps/MapAtlasPhoenix', 'Metadata/Items/Maps/MapWorldsPhoenix']
# The Shaper's Realm ['Metadata/Items/Maps/MapAtlasShapersRealm', 'Metadata/Items/Maps/MapWorldsShapersRealm']
# Harbinger Map ['Metadata/Items/Maps/MapAtlasHarbingerLow', 'Metadata/Items/Maps/MapAtlasHarbingerMid', 'Metadata/Items/Maps/MapAtlasHarbingerHigh', 'Metadata/Items/Maps/MapWorldsHarbingerLow', 'Metadata/Items/Maps/MapWorldsHarbingerMid', 'Metadata/Items/Maps/MapWorldsHarbingerHigh', 'Metadata/Items/Maps/MapWorldsHarbingerUber']
# Sacrifice at Midnight ['Metadata/Items/MapFragments/VaalFragment1_1', 'Metadata/Items/MapFragments/CurrencyVaalFragment1_1']
# Sacrifice at Dawn ['Metadata/Items/MapFragments/VaalFragment1_2', 'Metadata/Items/MapFragments/CurrencyVaalFragment1_2']
# Sacrifice at Noon ['Metadata/Items/MapFragments/VaalFragment1_3', 'Metadata/Items/MapFragments/CurrencyVaalFragment1_3']
# Sacrifice at Dusk ['Metadata/Items/MapFragments/VaalFragment1_4', 'Metadata/Items/MapFragments/CurrencyVaalFragment1_4']
# Mortal Rage ['Metadata/Items/MapFragments/VaalFragment2_1', 'Metadata/Items/MapFragments/CurrencyVaalFragment2_1']
# Mortal Hope ['Metadata/Items/MapFragments/VaalFragment2_2', 'Metadata/Items/MapFragments/CurrencyVaalFragment2_2']
# Mortal Ignorance ['Metadata/Items/MapFragments/VaalFragment2_3', 'Metadata/Items/MapFragments/CurrencyVaalFragment2_3']
# Mortal Grief ['Metadata/Items/MapFragments/VaalFragment2_4', 'Metadata/Items/MapFragments/CurrencyVaalFragment2_4']
# Eber's Key ['Metadata/Items/MapFragments/ProphecyFragment1', 'Metadata/Items/MapFragments/CurrencyProphecyFragment1']
# Yriel's Key ['Metadata/Items/MapFragments/ProphecyFragment2', 'Metadata/Items/MapFragments/CurrencyProphecyFragment2']
# Inya's Key ['Metadata/Items/MapFragments/ProphecyFragment3', 'Metadata/Items/MapFragments/CurrencyProphecyFragment3']
# Volkuur's Key ['Metadata/Items/MapFragments/ProphecyFragment4', 'Metadata/Items/MapFragments/CurrencyProphecyFragment4']
# Fragment of the Phoenix ['Metadata/Items/MapFragments/ShaperFragment1', 'Metadata/Items/MapFragments/CurrencyShaperFragment1']
# Fragment of the Minotaur ['Metadata/Items/MapFragments/ShaperFragment2', 'Metadata/Items/MapFragments/CurrencyShaperFragment2']
# Fragment of the Chimera ['Metadata/Items/MapFragments/ShaperFragment3', 'Metadata/Items/MapFragments/CurrencyShaperFragment3']
# Fragment of the Hydra ['Metadata/Items/MapFragments/ShaperFragment4', 'Metadata/Items/MapFragments/CurrencyShaperFragment4']
# Divine Vessel ['Metadata/Items/MapFragments/FragmentPantheonFlask', 'Metadata/Items/MapFragments/CurrencyFragmentPantheonFlask']
# Voidborn Reliquary Key ['Metadata/Items/MapFragments/VoidbornVaultKey', 'Metadata/Items/MapFragments/TencentVoidbornVaultKey']
# Crimson Watchstone ['Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_1', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_2', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_3', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_4', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_5', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_6', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_7', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade1_8']
# Cobalt Watchstone ['Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_1', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_2', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_3', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_4', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_5', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_6', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_7', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade2_8']
# Viridian Watchstone ['Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_1', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_2', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_3', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_4', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_5', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_6', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_7', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade3_8']
# Golden Watchstone ['Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_1', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_2', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_3', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_4', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_5', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_6', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_7', 'Metadata/Items/AtlasUpgrades/AtlasRegionUpgrade4_8']
# Admiral Darnaw's Papers ['Metadata/Items/Heist/QuestItems/HeistFinalObjectiveQuestFaustus1', 'Metadata/Items/Heist/QuestItems/HeistFinalObjectiveQuestFaustus1B']
# Maven's Invitation: The Atlas ['Metadata/Items/MapFragments/Maven/MavenMapAtlas1', 'Metadata/Items/MapFragments/Maven/MavenMapAtlas2', 'Metadata/Items/MapFragments/Maven/MavenMapAtlas3', 'Metadata/Items/MapFragments/Maven/MavenMapAtlas4']
# Maven's Invitation: Haewark Hamlet ['Metadata/Items/MapFragments/Maven/MavenMapOutsideTopLeft1', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideTopLeft2', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideTopLeft3', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideTopLeft4']
# Maven's Invitation: Tirn's End ['Metadata/Items/MapFragments/Maven/MavenMapInsideTopLeft1', 'Metadata/Items/MapFragments/Maven/MavenMapInsideTopLeft2', 'Metadata/Items/MapFragments/Maven/MavenMapInsideTopLeft3', 'Metadata/Items/MapFragments/Maven/MavenMapInsideTopLeft4']
# Maven's Invitation: Lex Proxima ['Metadata/Items/MapFragments/Maven/MavenMapInsideTopRight1', 'Metadata/Items/MapFragments/Maven/MavenMapInsideTopRight2', 'Metadata/Items/MapFragments/Maven/MavenMapInsideTopRight3', 'Metadata/Items/MapFragments/Maven/MavenMapInsideTopRight4']
# Maven's Invitation: Lex Ejoris ['Metadata/Items/MapFragments/Maven/MavenMapOutsideTopRight1', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideTopRight2', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideTopRight3', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideTopRight4']
# Maven's Invitation: New Vastir ['Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomLeft1', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomLeft2', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomLeft3', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomLeft4']
# Maven's Invitation: Glennach Cairns ['Metadata/Items/MapFragments/Maven/MavenMapInsideBottomLeft1', 'Metadata/Items/MapFragments/Maven/MavenMapInsideBottomLeft2', 'Metadata/Items/MapFragments/Maven/MavenMapInsideBottomLeft3', 'Metadata/Items/MapFragments/Maven/MavenMapInsideBottomLeft4']
# Maven's Invitation: Valdo's Rest ['Metadata/Items/MapFragments/Maven/MavenMapInsideBottomRight1', 'Metadata/Items/MapFragments/Maven/MavenMapInsideBottomRight2', 'Metadata/Items/MapFragments/Maven/MavenMapInsideBottomRight3', 'Metadata/Items/MapFragments/Maven/MavenMapInsideBottomRight4']
# Maven's Invitation: Lira Arthain ['Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomRight1', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomRight2', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomRight3', 'Metadata/Items/MapFragments/Maven/MavenMapOutsideBottomRight4']
#  ['Metadata/Items/Currency/RandomFossilOutcome1', 'Metadata/Items/Currency/RandomFossilOutcome2', 'Metadata/Items/Currency/RandomFossilOutcome3', 'Metadata/Items/Currency/RandomFossilOutcome4', 'Metadata/Items/Currency/RandomFossilOutcome5', 'Metadata/Items/Currency/RandomFossilOutcome6', 'Metadata/Items/Currency/RandomFossilOutcome7', 'Metadata/Items/Currency/RandomFossilOutcome8', 'Metadata/Items/Currency/RandomFossilOutcome9', 'Metadata/Items/Currency/RandomFossilOutcome10', 'Metadata/Items/Currency/RandomFossilOutcome11', 'Metadata/Items/Currency/RandomFossilOutcome12', 'Metadata/Items/Currency/RandomFossilOutcome13', 'Metadata/Items/Currency/RandomFossilOutcome14', 'Metadata/Items/Currency/RandomFossilOutcome15', 'Metadata/Items/Currency/RandomFossilOutcome16', 'Metadata/Items/Currency/RandomFossilOutcome17', 'Metadata/Items/Currency/RandomFossilOutcome18', 'Metadata/Items/Currency/RandomFossilOutcome19', 'Metadata/Items/Currency/RandomFossilOutcome20', 'Metadata/Items/Currency/RandomFossilOutcome21', 'Metadata/Items/Currency/RandomFossilOutcome22', 'Metadata/Items/Currency/RandomFossilOutcome23', 'Metadata/Items/Currency/RandomFossilOutcome24', 'Metadata/Items/Currency/RandomFossilOutcome25', 'Metadata/Items/Currency/RandomFossilOutcome26', 'Metadata/Items/Currency/RandomFossilOutcome27', 'Metadata/Items/Currency/RandomFossilOutcome28', 'Metadata/Items/Currency/RandomFossilOutcome29', 'Metadata/Items/Currency/RandomFossilOutcome30', 'Metadata/Items/Currency/RandomFossilOutcome31', 'Metadata/Items/Currency/RandomFossilOutcome32', 'Metadata/Items/Currency/RandomFossilOutcome33', 'Metadata/Items/Currency/RandomFossilOutcome34', 'Metadata/Items/Currency/RandomFossilOutcome35', 'Metadata/Items/Currency/RandomFossilOutcome36', 'Metadata/Items/Currency/RandomFossilOutcome37', 'Metadata/Items/Currency/RandomFossilOutcome38', 'Metadata/Items/Currency/RandomFossilOutcome39', 'Metadata/Items/Currency/RandomFossilOutcome40', 'Metadata/Items/Currency/RandomFossilOutcome41', 'Metadata/Items/Currency/RandomFossilOutcome42', 'Metadata/Items/Currency/RandomFossilOutcome43', 'Metadata/Items/Currency/RandomFossilOutcome44', 'Metadata/Items/Currency/RandomFossilOutcome45', 'Metadata/Items/Currency/RandomFossilOutcome46', 'Metadata/Items/Currency/RandomFossilOutcome47', 'Metadata/Items/Currency/RandomFossilOutcome48', 'Metadata/Items/Currency/RandomFossilOutcome49', 'Metadata/Items/Currency/RandomFossilOutcome50', 'Metadata/Items/Currency/RandomFossilOutcome51', 'Metadata/Items/Currency/RandomFossilOutcome52', 'Metadata/Items/Currency/RandomFossilOutcome53', 'Metadata/Items/Currency/RandomFossilOutcome54', 'Metadata/Items/Currency/RandomFossilOutcome55', 'Metadata/Items/Currency/RandomFossilOutcome56', 'Metadata/Items/Currency/RandomFossilOutcome57', 'Metadata/Items/Currency/RandomFossilOutcome58', 'Metadata/Items/Currency/RandomFossilOutcome59', 'Metadata/Items/Currency/RandomFossilOutcome60', 'Metadata/Items/Currency/RandomFossilOutcome61', 'Metadata/Items/Currency/RandomFossilOutcome62', 'Metadata/Items/Currency/RandomFossilOutcome63', 'Metadata/Items/Currency/RandomFossilOutcome64', 'Metadata/Items/Currency/RandomFossilOutcome65', 'Metadata/Items/Currency/RandomFossilOutcome66', 'Metadata/Items/Currency/RandomFossilOutcome67', 'Metadata/Items/Currency/RandomFossilOutcome68', 'Metadata/Items/Currency/RandomFossilOutcome69', 'Metadata/Items/Currency/RandomFossilOutcome70', 'Metadata/Items/Currency/RandomFossilOutcome71', 'Metadata/Items/Currency/RandomFossilOutcome72', 'Metadata/Items/Currency/RandomFossilOutcome73', 'Metadata/Items/Currency/RandomFossilOutcome74', 'Metadata/Items/Currency/RandomFossilOutcome75', 'Metadata/Items/Currency/RandomFossilOutcome76', 'Metadata/Items/Currency/RandomFossilOutcome77', 'Metadata/Items/Currency/RandomFossilOutcome78', 'Metadata/Items/Currency/RandomFossilOutcome79', 'Metadata/Items/Currency/RandomFossilOutcome80', 'Metadata/Items/Currency/RandomFossilOutcome81', 'Metadata/Items/Currency/RandomFossilO ...
# Sanctified Relic ['Metadata/Items/Relics/SanctumSpecialRelic1', 'Metadata/Items/Relics/SanctumSpecialRelic2', 'Metadata/Items/Relics/SanctumSpecialRelic3']
# Ironwood Tincture ['Metadata/Items/Tinctures/TinctureStun', 'Metadata/Items/Tinctures/Tincture3']
# Ashbark Tincture ['Metadata/Items/Tinctures/TinctureIgnite', 'Metadata/Items/Tinctures/Tincture4']
# Fulgurite Tincture ['Metadata/Items/Tinctures/TinctureShock', 'Metadata/Items/Tinctures/Tincture6']
# Poisonberry Tincture ['Metadata/Items/Tinctures/TincturePoison', 'Metadata/Items/Tinctures/Tincture7']
# Rosethorn Tincture ['Metadata/Items/Tinctures/TinctureCriticalStrike', 'Metadata/Items/Tinctures/Tincture2']
# Oakbranch Tincture ['Metadata/Items/Tinctures/TinctureCullingStrike', 'Metadata/Items/Tinctures/Tincture9']
# Borealwood Tincture ['Metadata/Items/Tinctures/TinctureFreeze', 'Metadata/Items/Tinctures/Tincture5']
# Blood Sap Tincture ['Metadata/Items/Tinctures/TinctureBleed', 'Metadata/Items/Tinctures/Tincture8']
